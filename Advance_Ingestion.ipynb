# %%
dbutils.widgets.text("filenames", "")
filenames = dbutils.widgets.get("filenames")

# %%
df=spark.read.format("parquet")\
    .load(f'/Volumes/db_jobs/edw/raw_data/{filenames}.parquet')
# display(df)
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save(f'/Volumes/db_jobs/edw/raw_data/sink/{filenames}')
